# %% [markdown]
# # Use LORA to finetune caption model

# %% [markdown]
# ## Blip

# %% [markdown]
# ### Load model and dataset

# %%
import os
! cd "/home/changl25/Image-to-text-of-Stable-Diffusion"
work_dir = "/home/changl25/Image-to-text-of-Stable-Diffusion"
os.chdir(work_dir)

# %%
! ls "/data/changl25/Diffusion2DB/part-000002"
data_dir = "/data/changl25/Diffusion2DB"
os.chdir(data_dir)

# %%
from urllib.request import urlretrieve
import shutil
part_id = 1
part_url = f'https://huggingface.co/datasets/poloclub/diffusiondb/resolve/main/images/part-{part_id:06}.zip'
shutil.unpack_archive(f'part-{part_id:06}.zip', f'part-{part_id:06}')
urlretrieve(part_url, f'part-{part_id:06}.zip')
part_id = 2
part_url = f'https://huggingface.co/datasets/poloclub/diffusiondb/resolve/main/images/part-{part_id:06}.zip'
urlretrieve(part_url, f'part-{part_id:06}.zip')
shutil.unpack_archive(f'part-{part_id:06}.zip', f'part-{part_id:06}')
# Out:
# ('part-000002.zip', <http.client.HTTPMessage at 0x2ab32ecea860>)

# %%
import torch
from dataset_diffusionDB import DiffusionDB
from transformers import BlipProcessor, BlipForConditionalGeneration
from peft import LoraConfig, get_peft_model
from torch.utils.data import DataLoader
import numpy as np

from tqdm.auto import tqdm

# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
precision="float32"
# Out:
# /home/changl25/miniconda3/envs/img2text/lib/python3.10/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11050). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base", torch_dtype=torch.float16).to(device) if precision == "float16" \
    else  BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base").to(device)

# %%
model  = model.to()

# %%
from transformers import CLIPTextModel, CLIPTokenizer
clip_tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")
clip_text_encoder = CLIPTextModel.from_pretrained("openai/clip-vit-large-patch14").to(device)

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
def print_model_structures(model):
    for name, module in model.named_modules():
        print("name: ", name)
        print("module.module: ", list(module.modules()))

# %%
model
# Out:
# BlipForConditionalGeneration(
#   (vision_model): BlipVisionModel(
#     (embeddings): BlipVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (encoder): BlipEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x BlipEncoderLayer(
#           (self_attn): BlipAttention(
#             (dropout): Dropout(p=0.0, inplace=False)
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): BlipMLP(
#             (activation_fn): GELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (text_decoder): BlipTextLMHeadModel(
#     (bert): BlipTextModel(
#       (embeddings): BlipTextEmbeddings(
#         (word_embeddings): Embedding(30524, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (encoder): BlipTextEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BlipTextLayer(
#             (attention): BlipTextAttention(
#               (self): BlipTextSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): BlipTextSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (crossattention): BlipTextAttention(
#               (self): BlipTextSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): BlipTextSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BlipTextIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BlipTextOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (cls): BlipTextOnlyMLMHead(
#       (predictions): BlipTextLMPredictionHead(
#         (transform): BlipTextPredictionHeadTransform(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=768, out_features=30524, bias=True)
#       )
#     )
#   )
# )

# %%
print_trainable_parameters(model)
# Out:
# trainable params: 247414076 || all params: 247414076 || trainable%: 100.0

# %%
batch_size = 16
root_path = '/data/changl25/Diffusion2DB/part-000001'
test_dataset = DiffusionDB(root_path, text = "a photo of", transform=processor, test=True)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=True)
batch_size = 16
root_path = '/data/changl25/Diffusion2DB/part-000002'
train_dataset = DiffusionDB(root_path, text = "a photo of", transform=processor)
train_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=True)

# %%
! ls /data/changl25/img2textModel/blip_model
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# config.json  generation_config.json  model.safetensors

# %% [markdown]
# ### LoRA config

# %%
config = LoraConfig(
    r = 4,
    lora_alpha = 32, 
    lora_dropout = 0.05,
    bias = "none",
    target_modules = ["query", "value"]
)

peft_model = get_peft_model(model, config)
peft_model = peft_model.to(device)

# %%
print_trainable_parameters(peft_model)
# Out:
# trainable params: 294912 || all params: 247708988 || trainable%: 0.11905583337169824

# %%
optimizer = torch.optim.AdamW(peft_model.parameters(), lr=1e-4)
epochs = 50

# %%
import time
def sd_encoder(text, tokenizer, encoder):
    input = tokenizer(text, padding="max_length", max_length=tokenizer.model_max_length, truncation=True, return_tensors="pt")
    input_ids = input["input_ids"].to(device)
    embeddings = encoder(input_ids)[0]
    return embeddings

def clip_cos_similarity(output_prompt, prompts):
    caption_embeddings = sd_encoder(output_prompt, clip_tokenizer, clip_text_encoder)
    prompt_embeddings = sd_encoder(prompts, clip_tokenizer, clip_text_encoder)
    prompt_embeds_flat = prompt_embeddings.view(prompt_embeddings.size(0), -1)
    caption_embeds_flat = caption_embeddings.view(caption_embeddings.size(0), -1)
    prompt_embeds = prompt_embeds_flat / prompt_embeds_flat.norm(dim=1, keepdim=True)
    caption_embeds = caption_embeds_flat / caption_embeds_flat.norm(dim=1, keepdim=True)
    similarity = (torch.matmul(prompt_embeds, caption_embeds.t())).mean()
    return similarity

def sentence_cos_similarity(output_prompt, prompts):
    import sys
    sys.path.append("/data/changl25/img2textModel/sentence-transformers/")
    from sentence_transformers import SentenceTransformer, models

    st_model = SentenceTransformer('/data/changl25/img2textModel/all-MiniLM-L6-v2')
    prompt_embedding = st_model.encode(prompts).flatten()
    output_embedding = st_model.encode(output_prompt).flatten()
    similarity = np.dot(prompt_embedding, output_embedding) / (np.linalg.norm(prompt_embedding) * np.linalg.norm(output_embedding))
    return similarity

def evaluate(peft_model, preprocessor, data_loader, text_flag, precision):
    loss = 0
    evaluate_text = []
    caption_text = []
    prompt_text = []
    peft_model.eval()
    
    loss_time = 0
    generate_time = 0
    load_time = 0
    with torch.no_grad():
        for i, data in enumerate(data_loader):
            start_time = time.time()
            inputs, inputs_generator, prompt = data
            for key, value in inputs.items():
                if precision == "float32":
                    inputs[key] = value.to(device)
                    inputs_generator[key] = inputs_generator[key].to(device)
                elif precision == "float16":
                    inputs[key] = value.to(device)
                    inputs_generator[key] = inputs_generator[key].to(device, torch.float16)
            if precision == "float32":
                labels = torch.tensor(preprocessor.tokenizer(text=prompt, padding="max_length")["input_ids"]).to(device)
            elif precision == "float16":
                labels = torch.tensor(preprocessor.tokenizer(text=prompt, padding="max_length")["input_ids"]).to(device, torch.float16)
            end_time3 = time.time()
            if text_flag:
                input_ids = inputs["input_ids"]
                pixel_values = inputs["pixel_values"]
                attention_mask = inputs["attention_mask"]
                outputs = peft_model(input_ids=input_ids, pixel_values=pixel_values,attention_mask=attention_mask, labels=labels)
            else:
                pixel_values = inputs["pixel_values"]
                outputs = peft_model(pixel_values=pixel_values, labels=labels)
            loss += outputs.loss / len(prompt)
            end_time1 = time.time()
            out = peft_model.generate(**inputs_generator)
            out_text = preprocessor.batch_decode(out, skip_special_tokens=True)
            end_time2 = time.time()
            evaluate_text.append((out_text, prompt))
            loss_time += (end_time1  - end_time3) / len(prompt)
            generate_time += (end_time2  - end_time1) / len(prompt)
            load_time += (end_time3 - start_time) / len(prompt)
    start_time = time.time()        
    for i in range(len(evaluate_text)):
        output_text_batch, prompt_batch = evaluate_text[i]
        for j in range(len(output_text_batch)):
            output_text, prompt = output_text_batch[j], prompt_batch[j]
            caption_text.append(output_text)
            prompt_text.append(prompt)
    clip_sim = clip_cos_similarity(caption_text, prompt_text)
    sentence_sim = sentence_cos_similarity(caption_text, prompt_text)
    end_time = time.time()
    print(f"load time: {load_time / len(data_loader):.4f}, loss time: {loss_time / len(data_loader)}, generate time: {generate_time / len(data_loader)}, similar time: {(end_time - start_time) / len(caption_text)}")
    return loss / len(data_loader), clip_sim, sentence_sim

# %%
loss, clip_similarity, sentence_similarity = evaluate(model, processor, test_loader, test_dataset.is_text_supervised(), precision)
# Out:
# /home/changl25/miniconda3/envs/img2text/lib/python3.10/site-packages/transformers/generation/utils.py:1132: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# load time: 0.0004, loss time: 1.6894775756767817, generate time: 1.6949237776654107, similar time: 0.1320671010017395

# %%
# Out:
# tensor(1.1335)

# %%
def train_manual(peft_model, preprocessor, train_loader, test_loader, epochs, optimizer, precision, text_flag):
    for epoch in range(epochs):
        peft_model.train()
        for i, data in enumerate(train_loader):
            inputs, _, prompt = data
            for key, value in inputs.items():
                if precision == "float32":
                    inputs[key] = value.to(device)
                    labels = torch.tensor(preprocessor.tokenizer(text=prompt, padding="max_length")["input_ids"]).to(device)
                elif precision == "float16":
                    inputs[key] = value.to(device, torch.float16)
                    labels = torch.tensor(preprocessor.tokenizer(text=prompt, padding="max_length")["input_ids"]).to(device, torch.float16)
                    
            if text_flag:
                input_ids = inputs.pop("input_ids")
                pixel_values = inputs.pop("pixel_values")
                attention_mask = inputs.pop("attention_mask")
                outputs = peft_model(input_ids=input_ids, pixel_values=pixel_values,attention_mask=attention_mask,labels=labels)
            else:
                pixel_values = inputs.pop("pixel_values")
                outputs = peft_model(pixel_values=pixel_values, labels=labels)
            loss = outputs.loss
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            if (i + 1) % (len(train_loader) // 3) == 0:
                print(f"Epoch {epoch}: {i} / {len(train_loader)} {loss} ")
        evaluate_loss, similarity = evaluate(peft_model, preprocessor,test_loader, text_flag, precision)
        print(f"Epoch {epoch} final loss: {evaluate_loss}; similarity: {similarity}")

# %%
data = next(iter(train_loader))
peft_model.train()
inputs, prompt = data
for key, value in inputs.items():
    print(key)
    if precision == "float32":
        inputs[key] = value.to(device)
    elif precision == "float16":
        inputs[key] = value.to(device, torch.float16)
input_ids = inputs.pop("input_ids")
pixel_values = inputs.pop("pixel_values")
attention_mask = inputs.pop("attention_mask")
outputs = peft_model(input_ids=input_ids, pixel_values=pixel_values,attention_mask=attention_mask)
# Out:
# pixel_values
# input_ids
# attention_mask

# %%
evaluate(peft_model, test_loader, test_dataset.is_text_supervised(), precision)

# %%
train_manual(peft_model, processor, train_loader, test_loader, epochs, optimizer, precision, train_dataset.is_text_supervised())
# Out:
# Epoch 0: 1 / 7 12.801506042480469
# Epoch 0: 3 / 7 12.566864967346191
# Epoch 0: 5 / 7 12.68709659576416
# ('portrait of saitama, artstation winner by victo ngai, kilian eng and by jake parker, by conrad roset, swirly vibrant color lines, winning award masterpiece, fantastically gaudy, aesthetic, cinematic, octane render, 8 k, hd resolution ', 'a huge worm - man beast realistic cinematic 3 5 mm ', 'a geometrical portrait of a knave, fractal flowering background, digital art, analogous colours, trending on artstation, ', 'film still by 3 4 3 industries ', 'photo cartoon bd illustration comic manga painting of hangar environement : 5 fantasy environement, digital painting : 1 fat brush concept sketch artist bd enki bilal : 1 0 ', 'two vipers entwined, fighting to the death realistic cinematic 3 5 mm ', 'a beautiful painting of the heart of pripyat by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'landscape by zaha hadid, elysian retrowave morning sun universe vice city at night reclaimed by nature uv light neon signs at fall vaporwave, archdaily, wallpaper, highly detailed, trending on artstation. ', 'symmetry!! a tiny cute chinese spring festival oriental tale mascot eagle - phoenix dragon toys, magic, intricate, smooth line, light dust, mysterious dark background, warm top light, hd, 8 k, smooth ， sharp high quality artwork in style of greg rutkowski, concept art, blizzard warcraft artwork, bright colors ', 'cyberpunk baroque alucard, amber and obsidian, highly detailed, portrait, digital painting, trending on artstation, concept art, sharp focus, illustration, art by artgerm and greg rutkowski and magali villeneuve ', 'a beautiful painting of a retro futuristic stockholm, hyperdetailed, by simon stalenhag, artstation, pixiv, 8 k, octane render ', 'doom eternal, game concept art, veins and worms, muscular, exoskeleton, chiroptera head, chiroptera ears, shark teeth, ferocious, fierce, hyperrealism, fine details, artstation, cgsociety, zbrush, no background ', "a beautiful very detailed render of tiny home nature architecture unfinished building city by william pereira, neon noir darkacademia reclaimed by nature uv light nightvision assassin's creed fisheye thermal imaging cosmic cyberpunk, archdaily, wallpaper, highly detailed, trending on artstation. ", 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'architecture by mike winkelmann, magic realism elysian azeroth scumm bar alien lake neon signs retrowave cosmic universe, archdaily, wallpaper, highly detailed, trending on artstation. ', 'c 3 po looks like nick nolte with spaghetti in his mouth ')
# torch.Size([16, 512]) torch.Size([16, 512])
# /home/changl25/miniconda3/envs/img2text/lib/python3.10/site-packages/transformers/generation/utils.py:1132: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ('a star is born, in style of john harris, watercolor, artstation ', 'model in baggy colorful 9 0 s jacket by rick owens. magazine ad. pastel background. ', 'anthropomorphic racoon animal, dressed as a raver chick dancer, dance club in the forest, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'render of dreamy beautiful landscape, fantasy dreamy, ice kingdom, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'a painting by edward hopper of a busy and bustling city by contrast with the calming blue sky. ', 'by maxfield parrish, greg manchess, mucha ', 'an illustration of the second law of thermodynamics ', 'from the coast of north oregon, usa ( oc ) [ r / earthporn ] ', 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sachin teng and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'a beautiful ultradetailed anime illustration of unknown backroom level nature by bjarke ingels, landscape sunlight laser studio ghibli infrared cyberpunk at night synthwave tokyo vaporwave neon noir magic realism, archdaily, wallpaper, highly detailed, trending on artstation. ', 'white haired robe fu xi full male body portrait, sit upright on the ground, very long white beard and hair, fine kindness delicate prefect face features gaze, piercing eye, elegant, smooth, style of tom bagshaw, cedric peyravernay, peter mohrbacher, victo nga, 4 k hd illustrative wallpaper, animation style, chinese style ', 'anthropomorphic foxes animals, dressed as a raver chick dancer, dance club on tropical island, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'an emo portrait painting by edward hopper. short dark brown messy pixie haircut, large black eyes, antichrist eyes, slightly rounded face, pointed chin, thin lips, small nose, black tank top, black leather jacket, black knee - length skirt, black choker, black helmet, charcoal and ink splattered solarpunk portrait ', 'studio ghibli anime, adorable woman walking in the forest, romantic magical, fairytale, fantasy, pastel colors ', 'portrait of a cloaked female devil, demoness, evil, ominous, luscious, ginger hair, stunning, detailed, by artgerm, by greg rutkowski, by luis royo, by pixar, by myazaki, gothic, final fantasy, fantasy, medieval ', 'painted closeup portrait of tree man, masculine, fierce, charming, majestic, fantasy, intricate, elegant, extremely detailed digital painting, concept art, sharp focus illustration art by alphonse mucha by chuck close, charcoal on canvas ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('the last photo of a dodo alive sepia realistic 3 5 mm cinematic ', 'girl from fight club, digital collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke ', 'a hyperdetailed character design opulent, elderly grandmaster, fumo yoshitoshi, chinese mythology, ren jing jeong, peter mohrbacher, biomehieronymus spang, arunanondchai, murals, ocohopebright, pg 1 4 8, veileducationary, esllection, warrior, dreamcore, hyper detailed digital art, chinese style, vic', 'hyperrealistic portrait of a philippine character in a scenic environment, war, flowers, rain, by beksinski zdzislaw, yoro sean, buchholz, quint, christensen james c., ', 'portrait of a dancing eagle woman, beautiful blonde haired lakota sioux goddess, intricate, highly detailed art by james jean, ray tracing, digital painting, artstation, concept art, smooth, sharp focus, illustration, artgerm and greg rutkowski and alphonse mucha, vladimir kush, giger 8 k ', 'james graham ballard, highrise, sustainability, octane render, minimal design ', 'a beautiful painting of rainy pripyat by nekro and pascal blanche and syd mead and greg rutkowski and beeple and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'a beautiful painting of a retro futuristic stockholm, hyperdetailed, by simon stalenhag, cyberpunk, synthwave, digital illustration, concept art, wallpaper, artstation, pixiv, 8 k, octane render ', 'by ryan meinerding ', 'japaneese nymphomaniac, mixed media collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke, solid black background, contrasted, harmonic colors ', 'loreal paris by maxfield parrish, greg manchess, mucha ', 'concept art of a silent hill monster. painted by edward hopper. ', 'industrial spaceport on a vast city planet with ships taking off, by ralph mcquarrie, digital painting, highly detailed ', 'a car crawling with human hands and feet, surrealist landscape painting, high detail, weirdness, creepy ', 'a gummy bear performing at woodstock concert. 3 5 mm film, ', 'screenshot, 3 4 3, bungie, by concept artists at weta ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('a painting by edward hopper of a young woman in a floral dress. she has blue lines down her face, black hair and piercing eyes ', 'mount epic ashen pandaren phoenix screenshot world of warcraft mounts worldboss bioluminecant light concept sketch art and by feng zhu alena aenami artworks in 4 k beeple, by thomas kinkade heartstone overwatch blizzard 3 d rtx hdr ', 'mount epic undead cats screenshot world of warcraft mounts worldboss bioluminecant light concept sketch art and by feng zhu alena aenami artworks in 4 k beeple, by thomas kinkade heartstone overwatch blizzard 3 d rtx hdr ', 'a beautiful photorealistic illustration of greenhouse industrial architecture unfinished building by rosa bonheur, meadow forest at dusk vaporwave, archdaily, wallpaper, highly detailed, trending on artstation. ', 'neon japaneese nymphomaniac, mixed media collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke, contrasted, harmonic colors ', 'render of man lost in space, dreamy, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, by vladimir motsar, unreal engine, high detailed, 8 k ', 'george washington by kehinde wiley and rembrandt : 4. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up : 5. ', 'anthropomorphic foxes animals, dressed as hot raver girl dancers, dance club in tropical paradise, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'a hyperdetailed character design opulent, elderly grandmaster, fumo yoshitoshi, chinese mythology, ren jing jeong, peter mohrbacher, biomehieronymus spang, arunanondchai, murals, ocohopebright, pg 1 4 8, veileducationary, esllection, warrior, dreamcore, hyper detailed digital art, chinese style, vic', 'by artstation, cgsociety ', 'harrison ford by kehinde wiley and rembrandt : 5. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up : 5. ', 'a beautiful painting of rainy pripyat by nekro and pascal blanche and syd mead and greg rutkowski and beeple and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'a beautiful hyperdetailed anime illustration of arsenal building city nature architecture industrial architecture unfinished building urbex by claude lorrain, at night water at dusk cosmic crystal made of glass thermal vision mercury sunlight, archdaily, wallpaper, highly detailed, trending on artstation. ', 'hyperrealistic ultradetailed portrait of a crying philippine character in a scenic environment, war, flowers, rain, by beksinski zdzislaw, yoro sean, buchholz, quint, christensen james c., ', 'hyperrealistic portrait of a philippine character in a scenic environment, flowers, rain, by beksinski zdzislaw, yoro sean, buchholz quint, christensen james c., ', 'victo ngai poring decal design, highly detailed, high quality, digital painting, by ross tran and studio ghibli and alphonse mucha, artgerm ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('angel illustration by maxfield parrish, greg manchess, mucha ', 'render of dreamy beautiful landscape, dreamy, by herbaceous plants, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'highly detailed god erlang character design, chinese mythological style, cyberpunk, steampunk, in an elevator with art nouveau neon panelling, ultrawide angle, low camera angle, billowing smoke wisps, art by fenghua zhong, peter mohrbacher, ruan jia, liuyuan lange, akiya kageichi, ayami kojima, joseph leyendecker, vic', 'a snowing field of black flowers and white flowers in front, white mountains in background, wide angle, sad feeling, in style of john harris s, watercolor, artstation ', 'a close - up portrait of zack de la rocha painted by rembrandt, oil painting, baroque painting, highly detailed, 4 k ', 'george washington by kehinde wiley and rembrandt : 5. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up : 1. ', 'concept art of a citizen of the apocalypse, by ralph mcquarrie, concept art, highly detailed ', 'harrison ford by kehinde wiley and rembrandt. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up. ', 'a dog doing weights. epic oil painting. ', 'painted closeup portrait of intense woman, fierce, fantasy, intricate, elegant, extremely detailed by by chuck close, charcoal on canvas ', 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'corgi puppy, extremely cute, beautiful paper quilling, swirls, spirals ', 'render of dreamy beautiful landscape, fantasy dreamy, the gaint ring, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'a beautiful painting of a pyramid on the moon by nekro and pascal blanche and syd mead and greg rutkowski and sachin teng and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'highly detailed magician god holding a divine staff character design, cyberpunk crystal helmet and armor, cape, warframe, magician style, cyberpunk, elegant, highly detailed, ray tracing, smooth, sharp focus, art by fenghua zhong, peter mohrbacher, ruan jia, liuyuan lange, akiya kageichi, ayami kojima, joseph leyendecker ', 'lost by alena aenami ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('monsters playing board games, oil painting by justin gerard, deviantart, pixar, bright colors ', 'doom eternal, metro exodus, game concept art, veins and worms, muscular, crustacean exoskeleton, chiroptera head, chiroptera ears, mecha, ferocious, fierce, hyperrealism, fine details, artstation, cgsociety, zbrush, no background ', 'a centered render of beautiful landscape, dreamy, by herbaceous plants, artger, followed by conifers and temperate and warm temperate, details vintage polaroid photo hyper realistic ultra realistic photo realistic photography, ancient and prehistoric by bellotto bernardo, unreal engine, high detailed, 8 k ', 'a beautiful detailed painting of alley urbex architecture city by jacob van ruisdael, crystal flowers architecture island retrowave at night at dusk neon noir apocalyptic forest magic realism at spring rainforest, archdaily, wallpaper, highly detailed, trending on artstation. ', 'painted closeup portrait of elven man, masculine, fierce, charming, majestic, fantasy, intricate, elegant, extremely detailed digital painting, concept art, sharp focus illustration art by alphonse mucha by chuck close, charcoal on canvas ', 'lakshmi goddess of wealth, long black hair, beautiful face, background of golden coins, tom bagshaw ', 'beyonce by kehinde wiley and rembrandt. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up. ', 'west hightland white terrier, sweet, affectionate, tender, cute, old painting ', "a plate illustration of milton's paradise lost ", 'angel john singer sargent, maxfield parrish, greg manchess, mucha ', 'jabba the hut as batman, movie still, hd ', 'morty in a spacesuit roams the universemorty fights monsters in the universe, beautiful details, wide angle action shot, photorealistic, high end design, 8 k, octane render, neo tokyo nuclear holocaust background, mist, ornate, lasers, volumetric lighting - h 1 2 0 0 ', 'symmetry!! a tiny cute chinese spring festival oriental tale mascot panda - lion toys, magic, intricate, smooth line, light dust, mysterious dark background, warm top light, hd, 8 k, smooth ， sharp high quality artwork in style of greg rutkowski, concept art, blizzard warcraft artwork, bright colors ', 'a beautiful ultradetailed rendering of architecture industrial architecture urbex housebarn nature by norman foster, at dawn sunlight bladerunner 2 0 4 9 myst magic realism laser cgsociety crystal tundra sunset steampunk san andreas vice city nightvision cyberpunk sci - fi at dusk, archdaily, wallpaper, highly detailed, trending on artstation. ', 'highly detailed, black male anthro - lynx, human with head of lynx and six nipples, long rockstar hair, facial scar, hairy masculine gigachad, muscular, wearing kilt and gold armbands, fur texture, on steps of alien temple, trending on artstation, ', 'stunning god of feline skull portrait, skull, furry, crimson, fantasy, intricate, elegant, highly detailed, digital painting, artstation, concept art, smooth, sharp focus, illustration, art by afshar petros and krenz cushart and artem demura and tony sandoval ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('harrison ford by kehinde wiley and rembrandt. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up. ', 'a man being devoured by hundreds of slugs realistic cinematic 3 5 mm ', 'painted closeup portrait of tree man, masculine, fierce, charming, majestic, fantasy, intricate, elegant, extremely detailed digital painting, concept art, sharp focus illustration art by alphonse mucha by chuck close, charcoal on canvas ', 'an icecream man melting ')
# torch.Size([4, 512]) torch.Size([4, 512])
# Epoch 0 final loss: 1.128335952758789; similarity: 0
# Epoch 1: 1 / 7 12.637130737304688
# Epoch 1: 3 / 7 12.558350563049316
# Epoch 1: 5 / 7 12.463704109191895
# ('girl from fight club, digital collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke ', 'a gummy bear performing at woodstock concert. 3 5 mm film, ', 'lost by alena aenami ', 'a dog doing weights. epic oil painting. ', 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sachin teng and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'a snowing field of black flowers and white flowers in front, white mountains in background, wide angle, sad feeling, in style of john harris s, watercolor, artstation ', 'angel illustration by maxfield parrish, greg manchess, mucha ', 'white haired robe fu xi full male body portrait, sit upright on the ground, very long white beard and hair, fine kindness delicate prefect face features gaze, piercing eye, elegant, smooth, style of tom bagshaw, cedric peyravernay, peter mohrbacher, victo nga, 4 k hd illustrative wallpaper, animation style, chinese style ', 'screenshot, 3 4 3, bungie, by concept artists at weta ', 'concept art of a citizen of the apocalypse, by ralph mcquarrie, concept art, highly detailed ', 'george washington by kehinde wiley and rembrandt : 4. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up : 5. ', 'anthropomorphic foxes animals, dressed as hot raver girl dancers, dance club in tropical paradise, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'highly detailed, black male anthro - lynx, human with head of lynx and six nipples, long rockstar hair, facial scar, hairy masculine gigachad, muscular, wearing kilt and gold armbands, fur texture, on steps of alien temple, trending on artstation, ', 'studio gh
the universemorty fights monsters in the universe, beautiful details, wide angle action shot, photorealistic, high end design, 8 k, octane render, neo tokyo nuclear holocaust background, mist, ornate, lasers, volumetric lighting - h 1 2 0 0 ', 'a painting by edward hopper of a busy and bustling city by contrast with the calming blue sky. ', 'by ryan meinerding ', 'model in baggy colorful 9 0 s jacket by rick owens. magazine ad. pastel background. ', 'by artstation, cgsociety ', 'portrait of saitama, artstation winner by victo ngai, kilian eng and by jake parker, by conrad roset, swirly vibrant color lines, winning award masterpiece, fantastically gaudy, aesthetic, cinematic, octane render, 8 k, hd resolution ', 'a huge worm - man beast realistic cinematic 3 5 mm ', 'a beautiful hyperdetailed anime illustration of arsenal building city nature architecture industrial architecture unfinished building urbex by claude lorrain, at night water at dusk cosmic crystal made of glass thermal vision mercury sunlight, archdaily, wallpaper, highly detailed, trending on artstation. ', 'a car crawling with human hands and feet, surrealist landscape painting, high detail, weirdness, creepy ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('loreal paris by maxfield parrish, greg manchess, mucha ', 'a beautiful painting of rainy pripyat by nekro and pascal blanche and syd mead and greg rutkowski and beeple and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'hyperrealistic ultradetailed portrait of a crying philippine character in a scenic environment, war, flowers, rain, by beksinski zdzislaw, yoro sean, buchholz, quint, christensen james c., ', 'hyperrealistic portrait of a philippine character in a scenic environment, flowers, rain, by beksinski zdzislaw, yoro sean, buchholz quint, christensen james c., ', 'a beautiful painting of the heart of pripyat by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'render of dreamy beautiful landscape, dreamy, by herbaceous plants, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'a star is born, in style of john harris, watercolor, artstation ', 'japaneese nymphomaniac, mixed media collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke, solid black background, contrasted, harmonic colors ', 'a beautiful ultradetailed anime illustration of unknown backroom level nature by bjarke ingels, landscape sunlight laser studio ghibli infrared cyberpunk at night synthwave tokyo vaporwave neon noir magic realism, archdaily, wallpaper, highly detailed, trending on artstation. ', 'anthropomorphic foxes animals, dressed as a raver chick dancer, dance club on tropical island, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'c 3 po looks like nick nolte with spaghetti in his mouth ', 'neon japaneese nymphomaniac, mixed media collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke, contrasted, harmonic colors ', 'film still by 3 4 3 industries ', 'by
# torch.Size([16, 512]) torch.Size([16, 512])
# ('a centered render of beautiful landscape, dreamy, by herbaceous plants, artger, followed by conifers and temperate and warm temperate, details vintage polaroid photo hyper realistic ultra realistic photo realistic photography, ancient and prehistoric by bellotto bernardo, unreal engine, high detailed, 8 k ', 'beyonce by kehinde wiley and rembrandt. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up. ', 'render of man lost in space, dreamy, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, by vladimir motsar, unreal engine, high detailed, 8 k ', 'architecture by mike winkelmann, magic realism elysian azeroth scumm bar alien lake neon signs retrowave cosmic universe, archdaily, wallpaper, highly detailed, trending on artstation. ')
# torch.Size([4, 512]) torch.Size([4, 512])
# Epoch 1 final loss: 1.1159086227416992; similarity: 0
# Epoch 2: 1 / 7 12.44938850402832
# Epoch 2: 3 / 7 12.471921920776367
# Epoch 2: 5 / 7 12.32083797454834
# ('stunning god of feline skull portrait, skull, furry, crimson, fantasy, intricate, elegant, highly detailed, digital painting, artstation, concept art, smooth, sharp focus, illustration, art by afshar petros and krenz cushart and artem demura and tony sandoval ', 'a huge worm - man beast realistic cinematic 3 5 mm ', 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'a star is born, in style of john harris, watercolor, artstation ', 'a beautiful painting of a retro futuristic stockholm, hyperdetailed, by simon stalenhag, cyberpunk, synthwave, digital illustration, concept art, wallpaper, artstation, pixiv, 8 k, octane render ', 'japaneese nymphomaniac, mixed media collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke, solid black background, contrasted, harmonic colors ', 'painted closeup portrait of intense woman, fierce, fantasy, intricate, elegant, extremely detailed by by chuck close, charcoal on canvas ', 'render of man lost in space, dreamy, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, by vladimir motsar, unreal engine, high detailed, 8 k ', 'a beautiful hyperdetailed anime illustration of arsenal building city nature architecture industrial architecture unfinished building urbex by claude lorrain, at night water at dusk cosmic crystal made of glass thermal vision mercury sunlight, archdaily, wallpaper, highly detailed, trending on artstation. ', 'highly detailed, black male anthro - lynx, human with head of lynx and six nipples, long rockstar hair, facial scar, hairy masculine gigachad, muscular, wearing kilt and gold armbands, fur texture, on steps of alien temple, trending on artstation, ', 'symmetry!! a tiny cute chinese spring festival oriental tale mascot panda - lion toys, magic, intricate, smooth line, light dust, mysterious dark background, warm top light, hd, 8 k, smooth ， sharp high quality artwork in style of greg rutkowski, concept art, blizzard warcraft artwork, bright colors ', 'monsters playing board games, oil painting by justin gerard, deviantart, pixar, bright colors ', 'a beautiful painting of rainy pripyat by nekro and pascal blanche and syd mead and greg rutkowski and beeple and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'girl from fight club, digital collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke ', 'model in baggy colorful 9 0 s jacket by rick owens. magazine ad. pastel background. ', 'landscape by zaha hadid, elysian retrowave morning sun universe vice city at night reclaimed by nature uv light neon signs at fall vaporwave, archdaily, wallpaper, highly detailed, trending on artstation. ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('concept art of a citizen of the apocalypse, by ralph mcquarrie, concept art, highly detailed ', 'highly detailed magician god holding a divine staff character design, cyberpunk crystal helmet and armor, cape, warframe, magician style, cyberpunk, elegant, highly detailed, ray tracing, smooth, sharp focus, art by fenghua zhong, peter mohrbacher, ruan jia, liuyuan lange, akiya kageichi, ayami kojima, joseph leyendecker ', 'a beautiful ultradetailed rendering of architecture industrial architecture urbex housebarn nature by norman foster, at dawn sunlight bladerunner 2 0 4 9 myst magic realism laser cgsociety crystal tundra sunset steampunk san andreas vice city nightvision cyberpunk sci - fi at dusk, archdaily, wallpaper, highly detailed, trending on artstation. ', "a beautiful very detailed render of tiny home nature architecture unfinished building city by william pereira, neon noir darkacademia reclaimed by nature uv light nightvision assassin's creed fisheye thermal imaging cosmic cyberpunk, archdaily, wallpaper, highly detailed, trending on artstation. ", 'harrison ford by kehinde wiley and rembrandt : 5. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up : 5. ', 'painted closeup portrait of tree man, masculine, fierce, charming, majestic, fantasy, intricate, elegant, extremely detailed digital painting, concept art, sharp focus illustration art by alphonse mucha by chuck close, charcoal on canvas ', 'james graham ballard, highrise, sustainability, octane render, minimal design ', "a plate illustration of milton's paradise lost ", 'an illustration of the second law of thermodynamics ', 'an emo portrait painting by edward hopper. short dark brown messy pixie haircut, large black eyes, antichrist eyes, slightly rounded face, pointed chin, thin lips, small nose, black tank top, black leather jacket, black knee - length skirt, black choker, black helmet, charcoal and ink splattered solarpunk portrait ', 'painted closeup portrait of elven man, masculine, fierce, charming, majestic, fantasy, intricate, elegant, extremely detailed digital painting, concept art, sharp focus illustration art by alphonse mucha by chuck close, charcoal on canvas ', 'the last photo of a dodo alive sepia realistic 3 5 mm cinematic ', 'victo ngai poring decal design, highly detailed, high quality, digital painting, by ross tran and studio ghibli and alphonse mucha, artgerm ', 'a geometrical portrait of a knave, fractal flowering background, digital art, analogous colours, trending on artstation, ', 'a painting by edward hopper of a busy and bustling city by contrast with the calming blue sky. ', 'a gummy bear performing at woodstock concert. 3 5 mm film, ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ('a beautiful painting of the heart of pripyat by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'harrison ford by kehinde wiley and rembrandt. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up. ', 'doom eternal, metro exodus, game concept art, veins and worms, muscular, crustacean exoskeleton, chiroptera head, chiroptera ears, mecha, ferocious, fierce, hyperrealism, fine details, artstation, cgsociety, zbrush, no background ', 'render of dreamy beautiful landscape, fantasy dreamy, the gaint ring, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'angel john singer sargent, maxfield parrish, greg manchess, mucha ', 'morty in a spacesuit roams the universemorty fights monsters in the universe, beautiful details, wide angle action shot, photorealistic, high end design, 8 k, octane render, neo tokyo nuclear holocaust background, mist, ornate, lasers, volumetric lighting - h 1 2 0 0 ', 'portrait of a dancing eagle woman, beautiful blonde haired lakota sioux goddess, intricate, highly detailed art by james jean, ray tracing, digital painting, artstation, concept art, smooth, sharp focus, illustration, artgerm and greg rutkowski and alphonse mucha, vladimir kush, giger 8 k ', 'industrial spaceport on a vast city planet with ships taking off, by ralph mcquarrie, digital painting, highly detailed ', 'render of dreamy beautiful landscape, fantasy dreamy, ice kingdom, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'george washington by kehinde wiley and rembrandt : 4. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up : 5. ', 'film still by 3 4 3 industries ', 'anthropomorphic foxes animals, dressed as hot raver girl dancers, dance club in tropical paradise, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'angel illustration by maxfield parrish, greg manchess, mucha ', 'anthropomorphic foxes animals, dressed as a raver chick dancer, dance club on tropical island, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'corgi puppy, extremely cute, beautiful paper quilling, swirls, spirals ')
# torch.Size([16, 512]) torch.Size([16, 512])
# ...
# torch.Size([16, 512]) torch.Size([16, 512])
# ('a star is born, in style of john harris, watercolor, artstation ', 'victo ngai poring decal design, highly detailed, high quality, digital painting, by ross tran and studio ghibli and alphonse mucha, artgerm ', 'george washington by kehinde wiley and rembrandt : 5. photorealistic facial features, portrait, detailed face, ultra high details, large, close - up : 1. ', 'corgi puppy, extremely cute, beautiful paper quilling, swirls, spirals ', 'by maxfield parrish, greg manchess, mucha ', "a beautiful very detailed render of tiny home nature architecture unfinished building city by william pereira, neon noir darkacademia reclaimed by nature uv light nightvision assassin's creed fisheye thermal imaging cosmic cyberpunk, archdaily, wallpaper, highly detailed, trending on artstation. ", 'girl from fight club, digital collage, assemblage, photomontage, minimalist, contemporary art, punk
# torch.Size([16, 512]) torch.Size([16, 512])
# ('morty in a spacesuit roams the universemorty fights monsters in the universe, beautiful details, wide angle action shot, photorealistic, high end design, 8 k, octane render, neo tokyo nuclear holocaust background, mist, ornate, lasers, volumetric lighting - h 1 2 0 0 ', 'monsters playing board games, oil painting by justin gerard, deviantart, pixar, bright colors ', 'highly detailed, black male anthro - lynx, human with head of lynx and six nipples, long rockstar hair, facial scar, hairy masculine gigachad, muscular, wearing kilt and gold armbands, fur texture, on steps of alien temple, trending on artstation, ', 'anthropomorphic racoon animal, dressed as a raver chick dancer, dance club in the forest, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'a beautiful painting of the heart of pripyat by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'a painting by edward hopper of a young woman in a floral dress. she has blue lines down her face, black hair and piercing eyes ', 'painted closeup portrait of elven man, masculine, fierce, charming, majestic, fantasy, intricate, elegant, extremely detailed digital painting, concept art, sharp focus illustration art by alphonse mucha by chuck close, charcoal on canvas ', 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sin jong hun and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'from the coast of north oregon, usa ( oc ) [ r / earthporn ] ', 'hyperrealistic portrait of a philippine character in a scenic environment, flowers, rain, by beksinski zdzislaw, yoro sean, buchholz quint, christensen james c., ', 'architecture by mike winkelmann, magic realism elysian azeroth scumm bar alien lake neon signs retrowave cosmic universe, archdaily, wallpaper, highly detailed, trending on artstation. ', 'render of dreamy beautiful landscape, fantasy dreamy, ice kingdom, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'model in baggy colorful 9 0 s jacket by rick owens. magazine ad. pastel background. ', 'an emo portrait painting by edward hopper. short dark brown messy pixie haircut, large black eyes, antichrist eyes, slightly rounded face, pointed chin, thin lips, small nose, black tank top, black leather jacket, black knee - length skirt, black choker, black helmet, charcoal and ink splattered solarpunk portrait ', 'by artstation, cgsociety ', 'a close - up portrait of zack de la rocha painted by rembrandt, oil painting, baroque painting, highly detailed, 4 k ')
# torch.Size([16, 512]) torch.Size([16, 512])
# torch.Size([16, 512]) torch.Size([16, 512])
# ('james graham ballard, highrise, sustainability, octane render, minimal design ', 'a beautiful painting of chernobyl in autumn by nekro and pascal blanche and syd mead and greg rutkowski and sachin teng and victo ngai and simon stalenhag and chris voy. in style of cg art. ray tracing, cel shading, 3 d. ue 5. hyper detailed. realistic. maya. octane render. ', 'render of man lost in space, dreamy, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, by vladimir motsar, unreal engine, high detailed, 8 k ', 'a painting by edward hopper of a busy and bustling city by contrast with the calming blue sky. ', 'portrait of saitama, artstation winner by victo ngai, kilian eng and by jake parker, by conrad roset, swirly vibrant color lines, winning award masterpiece, fantastically gaudy, aesthetic, cinematic, octane render, 8 k, hd resolution ', 'japaneese nymphomaniac, mixed media collage, assemblage, photomontage, minimalist, contemporary art, punk art, photorealistic, portrait, expressionism, masterpiece, dynamic composition, spectacular quality, intricate oil details, shattered glass texture, neon, chains, smoke, solid black background, contrasted, harmonic colors ', 'from the coast of north oregon, usa ( oc ) [ r / earthporn ] ', 'anthropomorphic foxes animals, dressed as hot raver girl dancers, dance club in tropical paradise, many woodland creatures dancing, concept design, contrast, hot toys, kim jung gi, greg rutkowski, zabrocki, karlkka, jayison devadas, trending on artstation, 8 k, ultra wide angle, pincushion lens effect ', 'a beautiful photorealistic illustration of greenhouse industrial architecture unfinished building by rosa bonheur, meadow forest at dusk vaporwave, archdaily, wallpaper, highly detailed, trending on artstation. ', 'render of dreamy beautiful landscape, dreamy, by herbaceous plants, artger, large scale, details vintage photo hyper realistic ultra realistic photo realistic photography, unreal engine, high detailed, 8 k ', 'angel john singer sargent, maxfield parrish, greg manchess, mucha ', 'a beautiful painting of a retro futuristic stockholm, hyperdetailed, by simon stalenhag, artstation, pixiv, 8 k, octane render ', 'hyperrealistic portrait of a philippine character in a scenic environment, flowers, rain, by beksinski zdzislaw, yoro sean, buchholz quint, christensen james c., ', 'highly detailed god erlang character design, chinese mythological style, cyberpunk, steampunk, in an elevator with art nouveau neon panelling, ultrawide angle, low camera angle, billowing smoke wisps, art by fenghua zhong, peter mohrbacher, ruan jia, liuyuan lange, akiya kageichi, ayami kojima, joseph leyendecker, vic', 'c 3 po looks like nick nolte with spaghetti in his mouth ', 'a snowing field of black flowers and white flowers in front, white mountains in background, wide angle, sad feeling, in style of john harris s, watercolor, artstation ')
# torch.Size([16, 512]) torch.Size([16, 512])
# 无法连接到远程 Jupyter 服务器 "http://172.22.224.117:8888/"。验证服务器是否正在运行且可访问。

# %% [markdown]
# Current problems
# * What is the exact input? what parameters do we need and their meanings? like
#     * input_ids: labels or hint
#     * labels: encoded or not encoded?
#     * loss: how is it computed? what kind of loss function is used? if we need to finetune, do we need to change the loss?

# %%
model.save_pretrained("/data/changl25/img2textModel/blip_model")
# Out:
# True
